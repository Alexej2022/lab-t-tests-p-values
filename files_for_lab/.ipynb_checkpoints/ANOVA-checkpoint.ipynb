# %% [markdown]
# #  ANOVA
#
# In statistics, **Analysis of Variance (ANOVA)** is also used to analyze the differences among group means. The difference between t-test and ANOVA is the former is ued to compare two groups whereas the latter is used to compare three or more groups. [Read more about the difference between t-test and ANOVA](http://b.link/anova24).
#
# From the ANOVA test, you receive two numbers. The first number is called the **F-value** which indicates whether your null-hypothesis can be rejected. The critical F-value that rejects the null-hypothesis varies according to the number of total subjects and the number of subject groups in your experiment. In [this table](http://b.link/eda14) you can find the critical values of the F distribution. **If you are confused by the massive F-distribution table, don't worry. Skip F-value for now and study it at a later time. In this challenge you only need to look at the p-value.**
#
# The p-value is another number yielded by ANOVA which already takes the number of total subjects and the number of experiment groups into consideration. **Typically if your p-value is less than 0.05, you can declare the null-hypothesis is rejected.**
#
# In this challenge, we want to understand whether there are significant differences among various types of pokemons' `Total` value, i.e. Grass vs Poison vs Fire vs Dragon... There are many types of pokemons which makes it a perfect use case for ANOVA.

# %%
# Import libraries
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the text file
df = pd.read_csv('pokemon.txt')

# Write the dataframe to a CSV file
df.to_csv('pokemon.csv', index=False)
# https://www.kaggle.com/datasets/abcsds/pokemon #?

# %%
# Load the data:
pokemon = pd.read_csv('pokemon.csv')
pokemon = pokemon.drop(columns='#')
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %%
# pokemon.to_excel('pokemon.xlsx', index=False)

# %% [markdown]
# **To achieve our goal, we use three steps:**
#
# 1. **Extract the unique values of the pokemon types.**
#
# 1. **Select dataframes for each unique pokemon type.**
#
# 1. **Conduct ANOVA analysis across the pokemon types.**

# %% [markdown]
# #### First let's obtain the unique values of the pokemon types. These values should be extracted from Type 1 and Type 2 aggregated. Assign the unique values to a variable called `unique_types`.
#
# *Hint: the correct number of unique types is 19 including `NaN`. You can disregard `NaN` in next step.*

# %%
# Your code here
unique_types = pokemon.groupby(['Type 1','Type 2']).agg({'Type 1':pd.Series.nunique, 'Type 2':pd.Series.nunique})
unique_types
# Out:
#                  Type 1  Type 2
# Type 1 Type 2
# Bug    Electric       1       1
#        Fighting       1       1
#        Fire           1       1
#        Flying         1       1
#        Ghost          1       1
# ...                 ...     ...
# Water  Ice            1       1
#        Poison         1       1
#        Psychic        1       1
#        Rock           1       1
#        Steel          1       1
#
# [136 rows x 2 columns]

# %%
unique_types = unique_types.T

# %% [markdown]
# #### Second we will create a list named `pokemon_totals` to contain the `Total` values of each unique type of pokemons.
#
# Why we use a list instead of a dictionary to store the pokemon `Total`? It's because ANOVA only tells us whether there is a significant difference of the group means but does not tell which group(s) are significantly different. Therefore, we don't need know which `Total` belongs to which pokemon type.
#
# *Hints:*
#
# * Loop through `unique_types` and append the selected type's `Total` to `pokemon_groups`. Be sure to loop through BOTH `Type 1` and `Type 2` to cover all occurrances of each unique type.
# * Skip the `NaN` value in `unique_types`. `NaN` is a `float` variable which you can find out by using `type()`. The valid pokemon type values are all of the `str` type.
# * At the end, the length of your `pokemon_totals` should be 18.

# %%
# Your code here
pokemon_groups = []
def func(Type1, Type2):
    for i in Type1:
        for j in Type2:
            pokemon_groups.append(pokemon['Total'])

# %%
pokemon_groups.to_excel('pokemon_groups.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\1838970716.py in <module>
# ----> 1 pokemon_groups.to_excel('pokemon_groups.xlsx', index=False)
#
# AttributeError: 'list' object has no attribute 'to_excel'

# %%
# map() is used to substitute each value in a Series with another value.
list(map(func, pokemon['Type 1'], pokemon['Type 2']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\527179397.py in <module>
#       1 # map() is used to substitute each value in a Series with another value.
# ----> 2 list(map(func, pokemon['Type 1'], pokemon['Type 2']))
#
# ~\AppData\Local\Temp\ipykernel_11400\391579199.py in func(Type1, Type2)
#       3 def func(Type1, Type2):
#       4     for i in Type1:
# ----> 5         for j in Type2:
#       6             pokemon_groups.append(pokemon['Total'])
#
# TypeError: 'float' object is not iterable

# %%
def func(row):
    return [row['Type 1'], row['Type 2'], row['Total']]

pokemon_groups = pokemon.apply(func, axis=1)

# %%
pokemon_groups = list(map(func, zip(pokemon['Type 1'], pokemon['Type 2'], pokemon['Total'])))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\2618351430.py in <module>
# ----> 1 pokemon_groups = list(map(func, zip(pokemon['Type 1'], pokemon['Type 2'], pokemon['Total'])))
#
# ~\AppData\Local\Temp\ipykernel_11400\1736867011.py in func(row)
#       1 def func(row):
# ----> 2     return [row['Type 1'], row['Type 2'], row['Total']]
#       3
#       4 pokemon_groups = pokemon.apply(func, axis=1)
#
# TypeError: tuple indices must be integers or slices, not str

# %%
def func(Type1, Type2, Total):
    return [Type1, Type2, Total]

pokemon_groups = list(map(func, pokemon['Type 1'], pokemon['Type 2'], pokemon['Total']))

# %%
pokemon_groups = [[Type1, Type2, Total] for Type1, Type2, Total in zip(pokemon['Type 1'], pokemon['Type 2'], pokemon['Total'])]

# %%
pokemon_groups
# Out:
# [['Grass', 'Poison', 318],
#  ['Grass', 'Poison', 405],
#  ['Grass', 'Poison', 525],
#  ['Grass', 'Poison', 625],
#  ['Fire', nan, 309],
#  ['Fire', nan, 405],
#  ['Fire', 'Flying', 534],
#  ['Fire', 'Dragon', 634],
#  ['Fire', 'Flying', 634],
#  ['Water', nan, 314],
#  ['Water', nan, 405],
#  ['Water', nan, 530],
#  ['Water', nan, 630],
#  ['Bug', nan, 195],
#  ['Bug', nan, 205],
#  ['Bug', 'Flying', 395],
#  ['Bug', 'Poison', 195],
#  ['Bug', 'Poison', 205],
#  ['Bug', 'Poison', 395],
#  ['Bug', 'Poison', 495],
#  ['Normal', 'Flying', 251],
#  ['Normal', 'Flying', 349],
#  ['Normal', 'Flying', 479],
#  ['Normal', 'Flying', 579],
#  ['Normal', nan, 253],
#  ['Normal', nan, 413],
#  ['Normal', 'Flying', 262],
#  ['Normal', 'Flying', 442],
#  ['Poison', nan, 288],
#  ['Poison', nan, 438],
#  ['Electric', nan, 320],
#  ['Electric', nan, 485],
#  ['Ground', nan, 300],
#  ['Ground', nan, 450],
#  ['Poison', nan, 275],
#  ['Poison', nan, 365],
#  ['Poison', 'Ground', 505],
#  ['Poison', nan, 273],
#  ['Poison', nan, 365],
#  ['Poison', 'Ground', 505],
#  ['Fairy', nan, 323],
#  ['Fairy', nan, 483],
#  ['Fire', nan, 299],
#  ['Fire', nan, 505],
#  ['Normal', 'Fairy', 270],
#  ['Normal', 'Fairy', 435],
#  ['Poison', 'Flying', 245],
#  ['Poison', 'Flying', 455],
#  ['Grass', 'Poison', 320],
#  ['Grass', 'Poison', 395],
#  ['Grass', 'Poison', 490],
#  ['Bug', 'Grass', 285],
#  ['Bug', 'Grass', 405],
#  ['Bug', 'Poison', 305],
#  ['Bug', 'Poison', 450],
#  ['Ground', nan, 265],
#  ['Ground', nan, 405],
#  ['Normal', nan, 290],
#  ['Normal', nan, 440],
#  ['Water', nan, 320],
#  ['Water', nan, 500],
#  ['Fighting', nan, 305],
#  ['Fighting', nan, 455],
#  ['Fire', nan, 350],
#  ['Fire', nan, 555],
#  ['Water', nan, 300],
#  ['Water', nan, 385],
#  ['Water', 'Fighting', 510],
#  ['Psychic', nan, 310],
#  ['Psychic', nan, 400],
#  ['Psychic', nan, 500],
#  ['Psychic', nan, 590],
#  ['Fighting', nan, 305],
#  ['Fighting', nan, 405],
#  ['Fighting', nan, 505],
#  ['Grass', 'Poison', 300],
#  ['Grass', 'Poison', 390],
#  ['Grass', 'Poison', 490],
#  ['Water', 'Poison', 335],
#  ['Water', 'Poison', 515],
#  ['Rock', 'Ground', 300],
#  ['Rock', 'Ground', 390],
#  ['Rock', 'Ground', 495],
#  ['Fire', nan, 410],
#  ['Fire', nan, 500],
#  ['Water', 'Psychic', 315],
#  ['Water', 'Psychic', 490],
#  ['Water', 'Psychic', 590],
#  ['Electric', 'Steel', 325],
#  ['Electric', 'Steel', 465],
#  ['Normal', 'Flying', 352],
#  ['Normal', 'Flying', 310],
#  ['Normal', 'Flying', 460],
#  ['Water', nan, 325],
#  ['Water', 'Ice', 475],
#  ['Poison', nan, 325],
#  ['Poison', nan, 500],
#  ['Water', nan, 305],
#  ['Water', 'Ice', 525],
#  ['Ghost', 'Poison', 310],
#  ['Ghost', 'Poison', 405],
#  ['Ghost', 'Poison', 500],
#  ['Ghost', 'Poison', 600],
#  ['Rock', 'Ground', 385],
#  ['Psychic', nan, 328],
#  ['Psychic', nan, 483],
#  ['Water', nan, 325],
#  ['Water', nan, 475],
#  ['Electric', nan, 330],
#  ['Electric', nan, 480],
#  ['Grass', 'Psychic', 325],
#  ['Grass', 'Psychic', 520],
#  ['Ground', nan, 320],
#  ['Ground', nan, 425],
#  ['Fighting', nan, 455],
#  ['Fighting', nan, 455],
#  ['Normal', nan, 385],
#  ['Poison', nan, 340],
#  ['Poison', nan, 490],
#  ['Ground', 'Rock', 345],
#  ['Ground', 'Rock', 485],
#  ['Normal', nan, 450],
#  ['Grass', nan, 435],
#  ['Normal', nan, 490],
#  ['Normal', nan, 590],
#  ['Water', nan, 295],
#  ['Water', nan, 440],
#  ['Water', nan, 320],
#  ['Water', nan, 450],
#  ['Water', nan, 340],
#  ['Water', 'Psychic', 520],
#  ['Psychic', 'Fairy', 460],
#  ['Bug', 'Flying', 500],
#  ['Ice', 'Psychic', 455],
#  ['Electric', nan, 490],
#  ['Fire', nan, 495],
#  ['Bug', nan, 500],
#  ['Bug', 'Flying', 600],
#  ['Normal', nan, 490],
#  ['Water', nan, 200],
#  ['Water', 'Flying', 540],
#  ['Water', 'Dark', 640],
#  ['Water', 'Ice', 535],
#  ['Normal', nan, 288],
#  ['Normal', nan, 325],
#  ['Water', nan, 525],
#  ['Electric', nan, 525],
#  ['Fire', nan, 525],
#  ['Normal', nan, 395],
#  ['Rock', 'Water', 355],
#  ['Rock', 'Water', 495],
#  ['Rock', 'Water', 355],
#  ['Rock', 'Water', 495],
#  ['Rock', 'Flying', 515],
#  ['Rock', 'Flying', 615],
#  ['Normal', nan, 540],
#  ['Ice', 'Flying', 580],
#  ['Electric', 'Flying', 580],
#  ['Fire', 'Flying', 580],
#  ['Dragon', nan, 300],
#  ['Dragon', nan, 420],
#  ['Dragon', 'Flying', 600],
#  ['Psychic', nan, 680],
#  ['Psychic', 'Fighting', 780],
#  ['Psychic', nan, 780],
#  ['Psychic', nan, 600],
#  ['Grass', nan, 318],
#  ['Grass', nan, 405],
#  ['Grass', nan, 525],
#  ['Fire', nan, 309],
#  ['Fire', nan, 405],
#  ['Fire', nan, 534],
#  ['Water', nan, 314],
#  ['Water', nan, 405],
#  ['Water', nan, 530],
#  ['Normal', nan, 215],
#  ['Normal', nan, 415],
#  ['Normal', 'Flying', 262],
#  ['Normal', 'Flying', 442],
#  ['Bug', 'Flying', 265],
#  ['Bug', 'Flying', 390],
#  ['Bug', 'Poison', 250],
#  ['Bug', 'Poison', 390],
#  ['Poison', 'Flying', 535],
#  ['Water', 'Electric', 330],
#  ['Water', 'Electric', 460],
#  ['Electric', nan, 205],
#  ['Fairy', nan, 218],
#  ['Normal', 'Fairy', 210],
#  ['Fairy', nan, 245],
#  ['Fairy', 'Flying', 405],
#  ['Psychic', 'Flying', 320],
#  ['Psychic', 'Flying', 470],
#  ['Electric', nan, 280],
#  ['Electric', nan, 365],
#  ['Electric', nan, 510],
#  ['Electric', 'Dragon', 610],
#  ['Grass', nan, 490],
#  ['Water', 'Fairy', 250],
#  ['Water', 'Fairy', 420],
#  ['Rock', nan, 410],
#  ['Water', nan, 500],
#  ['Grass', 'Flying', 250],
#  ['Grass', 'Flying', 340],
#  ['Grass', 'Flying', 460],
#  ['Normal', nan, 360],
#  ['Grass', nan, 180],
#  ['Grass', nan, 425],
#  ['Bug', 'Flying', 390],
#  ['Water', 'Ground', 210],
#  ['Water', 'Ground', 430],
#  ['Psychic', nan, 525],
#  ['Dark', nan, 525],
#  ['Dark', 'Flying', 405],
#  ['Water', 'Psychic', 490],
#  ['Ghost', nan, 435],
#  ['Psychic', nan, 336],
#  ['Psychic', nan, 405],
#  ['Normal', 'Psychic', 455],
#  ['Bug', nan, 290],
#  ['Bug', 'Steel', 465],
#  ['Normal', nan, 415],
#  ['Ground', 'Flying', 430],
#  ['Steel', 'Ground', 510],
#  ['Steel', 'Ground', 610],
#  ['Fairy', nan, 300],
#  ['Fairy', nan, 450],
#  ['Water', 'Poison', 430],
#  ['Bug', 'Steel', 500],
#  ['Bug', 'Steel', 600],
#  ['Bug', 'Rock', 505],
#  ['Bug', 'Fighting', 500],
#  ['Bug', 'Fighting', 600],
#  ['Dark', 'Ice', 430],
#  ['Normal', nan, 330],
#  ['Normal', nan, 500],
#  ['Fire', nan, 250],
#  ['Fire', 'Rock', 410],
#  ['Ice', 'Ground', 250],
#  ['Ice', 'Ground', 450],
#  ['Water', 'Rock', 380],
#  ['Water', nan, 300],
#  ['Water', nan, 480],
#  ['Ice', 'Flying', 330],
#  ['Water', 'Flying', 465],
#  ['Steel', 'Flying', 465],
#  ['Dark', 'Fire', 330],
#  ['Dark', 'Fire', 500],
#  ['Dark', 'Fire', 600],
#  ['Water', 'Dragon', 540],
#  ['Ground', nan, 330],
#  ['Ground', nan, 500],
#  ['Normal', nan, 515],
#  ['Normal', nan, 465],
#  ['Normal', nan, 250],
#  ['Fighting', nan, 210],
#  ['Fighting', nan, 455],
#  ['Ice', 'Psychic', 305],
#  ['Electric', nan, 360],
#  ['Fire', nan, 365],
#  ['Normal', nan, 490],
#  ['Normal', nan, 540],
#  ['Electric', nan, 580],
#  ['Fire', nan, 580],
#  ['Water', nan, 580],
#  ['Rock', 'Ground', 300],
#  ['Rock', 'Ground', 410],
#  ['Rock', 'Dark', 600],
#  ['Rock', 'Dark', 700],
#  ['Psychic', 'Flying', 680],
#  ['Fire', 'Flying', 680],
#  ['Psychic', 'Grass', 600],
#  ['Grass', nan, 310],
#  ['Grass', nan, 405],
#  ['Grass', nan, 530],
#  ['Grass', 'Dragon', 630],
#  ['Fire', nan, 310],
#  ['Fire', 'Fighting', 405],
#  ['Fire', 'Fighting', 530],
#  ['Fire', 'Fighting', 630],
#  ['Water', nan, 310],
#  ['Water', 'Ground', 405],
#  ['Water', 'Ground', 535],
#  ['Water', 'Ground', 635],
#  ['Dark', nan, 220],
#  ['Dark', nan, 420],
#  ['Normal', nan, 240],
#  ['Normal', nan, 420],
#  ['Bug', nan, 195],
#  ['Bug', nan, 205],
#  ['Bug', 'Flying', 395],
#  ['Bug', nan, 205],
#  ['Bug', 'Poison', 385],
#  ['Water', 'Grass', 220],
#  ['Water', 'Grass', 340],
#  ['Water', 'Grass', 480],
#  ['Grass', nan, 220],
#  ['Grass', 'Dark', 340],
#  ['Grass', 'Dark', 480],
#  ['Normal', 'Flying', 270],
#  ['Normal', 'Flying', 430],
#  ['Water', 'Flying', 270],
#  ['Water', 'Flying', 430],
#  ['Psychic', 'Fairy', 198],
#  ['Psychic', 'Fairy', 278],
#  ['Psychic', 'Fairy', 518],
#  ['Psychic', 'Fairy', 618],
#  ['Bug', 'Water', 269],
#  ['Bug', 'Flying', 414],
#  ['Grass', nan, 295],
#  ['Grass', 'Fighting', 460],
#  ['Normal', nan, 280],
#  ['Normal', nan, 440],
#  ['Normal', nan, 670],
#  ['Bug', 'Ground', 266],
#  ['Bug', 'Flying', 456],
#  ['Bug', 'Ghost', 236],
#  ['Normal', nan, 240],
#  ['Normal', nan, 360],
#  ['Normal', nan, 490],
#  ['Fighting', nan, 237],
#  ['Fighting', nan, 474],
#  ['Normal', 'Fairy', 190],
#  ['Rock', nan, 375],
#  ['Normal', nan, 260],
#  ['Normal', nan, 380],
#  ['Dark', 'Ghost', 380],
#  ['Dark', 'Ghost', 480],
#  ['Steel', 'Fairy', 380],
#  ['Steel', 'Fairy', 480],
#  ['Steel', 'Rock', 330],
#  ['Steel', 'Rock', 430],
#  ['Steel', 'Rock', 530],
#  ['Steel', nan, 630],
#  ['Fighting', 'Psychic', 280],
#  ['Fighting', 'Psychic', 410],
#  ['Fighting', 'Psychic', 510],
#  ['Electric', nan, 295],
#  ['Electric', nan, 475],
#  ['Electric', nan, 575],
#  ['Electric', nan, 405],
#  ['Electric', nan, 405],
#  ['Bug', nan, 400],
#  ['Bug', nan, 400],
#  ['Grass', 'Poison', 400],
#  ['Poison', nan, 302],
#  ['Poison', nan, 467],
#  ['Water', 'Dark', 305],
#  ['Water', 'Dark', 460],
#  ['Water', 'Dark', 560],
#  ['Water', nan, 400],
#  ['Water', nan, 500],
#  ['Fire', 'Ground', 305],
#  ['Fire', 'Ground', 460],
#  ['Fire', 'Ground', 560],
#  ['Fire', nan, 470],
#  ['Psychic', nan, 330],
#  ['Psychic', nan, 470],
#  ['Normal', nan, 360],
#  ['Ground', nan, 290],
#  ['Ground', 'Dragon', 340],
#  ['Ground', 'Dragon', 520],
#  ['Grass', nan, 335],
#  ['Grass', 'Dark', 475],
#  ['Normal', 'Flying', 310],
#  ['Dragon', 'Flying', 490],
#  ['Dragon', 'Fairy', 590],
#  ['Normal', nan, 458],
#  ['Poison', nan, 458],
#  ['Rock', 'Psychic', 440],
#  ['Rock', 'Psychic', 440],
#  ['Water', 'Ground', 288],
#  ['Water', 'Ground', 468],
#  ['Water', nan, 308],
#  ['Water', 'Dark', 468],
#  ['Ground', 'Psychic', 300],
#  ['Ground', 'Psychic', 500],
#  ['Rock', 'Grass', 355],
#  ['Rock', 'Grass', 495],
#  ['Rock', 'Bug', 355],
#  ['Rock', 'Bug', 495],
#  ['Water', nan, 200],
#  ['Water', nan, 540],
#  ['Normal', nan, 420],
#  ['Normal', nan, 440],
#  ['Ghost', nan, 295],
#  ['Ghost', nan, 455],
#  ['Ghost', nan, 555],
#  ['Ghost', nan, 295],
#  ['Ghost', nan, 455],
#  ['Grass', 'Flying', 460],
#  ['Psychic', nan, 425],
#  ['Dark', nan, 465],
#  ['Dark', nan, 565],
#  ['Psychic', nan, 260],
#  ['Ice', nan, 300],
#  ['Ice', nan, 480],
#  ['Ice', nan, 580],
#  ['Ice', 'Water', 290],
#  ['Ice', 'Water', 410],
#  ['Ice', 'Water', 530],
#  ['Water', nan, 345],
#  ['Water', nan, 485],
#  ['Water', nan, 485],
#  ['Water', 'Rock', 485],
#  ['Water', nan, 330],
#  ['Dragon', nan, 300],
#  ['Dragon', nan, 420],
#  ['Dragon', 'Flying', 600],
#  ['Dragon', 'Flying', 700],
#  ['Steel', 'Psychic', 300],
#  ['Steel', 'Psychic', 420],
#  ['Steel', 'Psychic', 600],
#  ['Steel', 'Psychic', 700],
#  ['Rock', nan, 580],
#  ['Ice', nan, 580],
#  ['Steel', nan, 580],
#  ['Dragon', 'Psychic', 600],
#  ['Dragon', 'Psychic', 700],
#  ['Dragon', 'Psychic', 600],
#  ['Dragon', 'Psychic', 700],
#  ['Water', nan, 670],
#  ['Water', nan, 770],
#  ['Ground', nan, 670],
#  ['Ground', 'Fire', 770],
#  ['Dragon', 'Flying', 680],
#  ['Dragon', 'Flying', 780],
#  ['Steel', 'Psychic', 600],
#  ['Psychic', nan, 600],
#  ['Psychic', nan, 600],
#  ['Psychic', nan, 600],
#  ['Psychic', nan, 600],
#  ['Grass', nan, 318],
#  ['Grass', nan, 405],
#  ['Grass', 'Ground', 525],
#  ['Fire', nan, 309],
#  ['Fire', 'Fighting', 405],
#  ['Fire', 'Fighting', 534],
#  ['Water', nan, 314],
#  ['Water', nan, 405],
#  ['Water', 'Steel', 530],
#  ['Normal', 'Flying', 245],
#  ['Normal', 'Flying', 340],
#  ['Normal', 'Flying', 485],
#  ['Normal', nan, 250],
#  ['Normal', 'Water', 410],
#  ['Bug', nan, 194],
#  ['Bug', nan, 384],
#  ['Electric', nan, 263],
#  ['Electric', nan, 363],
#  ['Electric', nan, 523],
#  ['Grass', 'Poison', 280],
#  ['Grass', 'Poison', 515],
#  ['Rock', nan, 350],
#  ['Rock', nan, 495],
#  ['Rock', 'Steel', 350],
#  ['Rock', 'Steel', 495],
#  ['Bug', nan, 224],
#  ['Bug', 'Grass', 424],
#  ['Bug', 'Ground', 424],
#  ['Bug', 'Steel', 424],
#  ['Bug', 'Flying', 424],
#  ['Bug', 'Flying', 244],
#  ['Bug', 'Flying', 474],
#  ['Electric', nan, 405],
#  ['Water', nan, 330],
#  ['Water', nan, 495],
#  ['Grass', nan, 275],
#  ['Grass', nan, 450],
#  ['Water', nan, 325],
#  ['Water', 'Ground', 475],
#  ['Normal', nan, 482],
#  ['Ghost', 'Flying', 348],
#  ['Ghost', 'Flying', 498],
#  ['Normal', nan, 350],
#  ['Normal', nan, 480],
#  ['Normal', 'Fighting', 580],
#  ['Ghost', nan, 495],
#  ['Dark', 'Flying', 505],
#  ['Normal', nan, 310],
#  ['Normal', nan, 452],
#  ['Psychic', nan, 285],
#  ['Poison', 'Dark', 329],
#  ['Poison', 'Dark', 479],
#  ['Steel', 'Psychic', 300],
#  ['Steel', 'Psychic', 500],
#  ['Rock', nan, 290],
#  ['Psychic', 'Fairy', 310],
#  ['Normal', nan, 220],
#  ['Normal', 'Flying', 411],
#  ['Ghost', 'Dark', 485],
#  ['Dragon', 'Ground', 300],
#  ['Dragon', 'Ground', 410],
#  ['Dragon', 'Ground', 600],
#  ['Dragon', 'Ground', 700],
#  ['Normal', nan, 390],
#  ['Fighting', nan, 285],
#  ['Fighting', 'Steel', 525],
#  ['Fighting', 'Steel', 625],
#  ['Ground', nan, 330],
#  ['Ground', nan, 525],
#  ['Poison', 'Bug', 330],
#  ['Poison', 'Dark', 500],
#  ['Poison', 'Fighting', 300],
#  ['Poison', 'Fighting', 490],
#  ['Grass', nan, 454],
#  ['Water', nan, 330],
#  ['Water', nan, 460],
#  ['Water', 'Flying', 345],
#  ['Grass', 'Ice', 334],
#  ['Grass', 'Ice', 494],
#  ['Grass', 'Ice', 594],
#  ['Dark', 'Ice', 510],
#  ['Electric', 'Steel', 535],
#  ['Normal', nan, 515],
#  ['Ground', 'Rock', 535],
#  ['Grass', nan, 535],
#  ['Electric', nan, 540],
#  ['Fire', nan, 540],
#  ['Fairy', 'Flying', 545],
#  ['Bug', 'Flying', 515],
#  ['Grass', nan, 525],
#  ['Ice', nan, 525],
#  ['Ground', 'Flying', 510],
#  ['Ice', 'Ground', 530],
#  ['Normal', nan, 535],
#  ['Psychic', 'Fighting', 518],
#  ['Psychic', 'Fighting', 618],
#  ['Rock', 'Steel', 525],
#  ['Ghost', nan, 525],
#  ['Ice', 'Ghost', 480],
#  ['Electric', 'Ghost', 440],
#  ['Electric', 'Fire', 520],
#  ['Electric', 'Water', 520],
#  ['Electric', 'Ice', 520],
#  ['Electric', 'Flying', 520],
#  ['Electric', 'Grass', 520],
#  ['Psychic', nan, 580],
#  ['Psychic', nan, 580],
#  ['Psychic', nan, 580],
#  ['Steel', 'Dragon', 680],
#  ['Water', 'Dragon', 680],
#  ['Fire', 'Steel', 600],
#  ['Normal', nan, 670],
#  ['Ghost', 'Dragon', 680],
#  ['Ghost', 'Dragon', 680],
#  ['Psychic', nan, 600],
#  ['Water', nan, 480],
#  ['Water', nan, 600],
#  ['Dark', nan, 600],
#  ['Grass', nan, 600],
#  ['Grass', 'Flying', 600],
#  ['Normal', nan, 720],
#  ['Psychic', 'Fire', 600],
#  ['Grass', nan, 308],
#  ['Grass', nan, 413],
#  ['Grass', nan, 528],
#  ['Fire', nan, 308],
#  ['Fire', 'Fighting', 418],
#  ['Fire', 'Fighting', 528],
#  ['Water', nan, 308],
#  ['Water', nan, 413],
#  ['Water', nan, 528],
#  ['Normal', nan, 255],
#  ['Normal', nan, 420],
#  ['Normal', nan, 275],
#  ['Normal', nan, 370],
#  ['Normal', nan, 500],
#  ['Dark', nan, 281],
#  ['Dark', nan, 446],
#  ['Grass', nan, 316],
#  ['Grass', nan, 498],
#  ['Fire', nan, 316],
#  ['Fire', nan, 498],
#  ['Water', nan, 316],
#  ['Water', nan, 498],
#  ['Psychic', nan, 292],
#  ['Psychic', nan, 487],
#  ['Normal', 'Flying', 264],
#  ['Normal', 'Flying', 358],
#  ['Normal', 'Flying', 488],
#  ['Electric', nan, 295],
#  ['Electric', nan, 497],
#  ['Rock', nan, 280],
#  ['Rock', nan, 390],
#  ['Rock', nan, 515],
#  ['Psychic', 'Flying', 313],
#  ['Psychic', 'Flying', 425],
#  ['Ground', nan, 328],
#  ['Ground', 'Steel', 508],
#  ['Normal', nan, 445],
#  ['Normal', 'Fairy', 545],
#  ['Fighting', nan, 305],
#  ['Fighting', nan, 405],
#  ['Fighting', nan, 505],
#  ['Water', nan, 294],
#  ['Water', 'Ground', 384],
#  ['Water', 'Ground', 509],
#  ['Fighting', nan, 465],
#  ['Fighting', nan, 465],
#  ['Bug', 'Grass', 310],
#  ['Bug', 'Grass', 380],
#  ['Bug', 'Grass', 500],
#  ['Bug', 'Poison', 260],
#  ['Bug', 'Poison', 360],
#  ['Bug', 'Poison', 485],
#  ['Grass', 'Fairy', 280],
#  ['Grass', 'Fairy', 480],
#  ['Grass', nan, 280],
#  ['Grass', nan, 480],
#  ['Water', nan, 460],
#  ['Ground', 'Dark', 292],
#  ['Ground', 'Dark', 351],
#  ['Ground', 'Dark', 519],
#  ['Fire', nan, 315],
#  ['Fire', nan, 480],
#  ['Fire', 'Psychic', 540],
#  ['Grass', nan, 461],
#  ['Bug', 'Rock', 325],
#  ['Bug', 'Rock', 475],
#  ['Dark', 'Fighting', 348],
#  ['Dark', 'Fighting', 488],
#  ['Psychic', 'Flying', 490],
#  ['Ghost', nan, 303],
#  ['Ghost', nan, 483],
#  ['Water', 'Rock', 355],
#  ['Water', 'Rock', 495],
#  ['Rock', 'Flying', 401],
#  ['Rock', 'Flying', 567],
#  ['Poison', nan, 329],
#  ['Poison', nan, 474],
#  ['Dark', nan, 330],
#  ['Dark', nan, 510],
#  ['Normal', nan, 300],
#  ['Normal', nan, 470],
#  ['Psychic', nan, 290],
#  ['Psychic', nan, 390],
#  ['Psychic', nan, 490],
#  ['Psychic', nan, 290],
#  ['Psychic', nan, 370],
#  ['Psychic', nan, 490],
#  ['Water', 'Flying', 305],
#  ['Water', 'Flying', 473],
#  ['Ice', nan, 305],
#  ['Ice', nan, 395],
#  ['Ice', nan, 535],
#  ['Normal', 'Grass', 335],
#  ['Normal', 'Grass', 475],
#  ['Electric', 'Flying', 428],
#  ['Bug', nan, 315],
#  ['Bug', 'Steel', 495],
#  ['Grass', 'Poison', 294],
#  ['Grass', 'Poison', 464],
#  ['Water', 'Ghost', 335],
#  ['Water', 'Ghost', 480],
#  ['Water', nan, 470],
#  ['Bug', 'Electric', 319],
#  ['Bug', 'Electric', 472],
#  ['Grass', 'Steel', 305],
#  ['Grass', 'Steel', 489],
#  ['Steel', nan, 300],
#  ['Steel', nan, 440],
#  ['Steel', nan, 520],
#  ['Electric', nan, 275],
#  ['Electric', nan, 405],
#  ['Electric', nan, 515],
#  ['Psychic', nan, 335],
#  ['Psychic', nan, 485],
#  ['Ghost', 'Fire', 275],
#  ['Ghost', 'Fire', 370],
#  ['Ghost', 'Fire', 520],
#  ['Dragon', nan, 320],
#  ['Dragon', nan, 410],
#  ['Dragon', nan, 540],
#  ['Ice', nan, 305],
#  ['Ice', nan, 485],
#  ['Ice', nan, 485],
#  ['Bug', nan, 305],
#  ['Bug', nan, 495],
#  ['Ground', 'Electric', 471],
#  ['Fighting', nan, 350],
#  ['Fighting', nan, 510],
#  ['Dragon', nan, 485],
#  ['Ground', 'Ghost', 303],
#  ['Ground', 'Ghost', 483],
#  ['Dark', 'Steel', 340],
#  ['Dark', 'Steel', 490],
#  ['Normal', nan, 490],
#  ['Normal', 'Flying', 350],
#  ['Normal', 'Flying', 510],
#  ['Dark', 'Flying', 370],
#  ['Dark', 'Flying', 510],
#  ['Fire', nan, 484],
#  ['Bug', 'Steel', 484],
#  ['Dark', 'Dragon', 300],
#  ['Dark', 'Dragon', 420],
#  ['Dark', 'Dragon', 600],
#  ['Bug', 'Fire', 360],
#  ['Bug', 'Fire', 550],
#  ['Steel', 'Fighting', 580],
#  ['Rock', 'Fighting', 580],
#  ['Grass', 'Fighting', 580],
#  ['Flying', nan, 580],
#  ['Flying', nan, 580],
#  ['Electric', 'Flying', 580],
#  ['Electric', 'Flying', 580],
#  ['Dragon', 'Fire', 680],
#  ['Dragon', 'Electric', 680],
#  ['Ground', 'Flying', 600],
#  ['Ground', 'Flying', 600],
#  ['Dragon', 'Ice', 660],
#  ['Dragon', 'Ice', 700],
#  ['Dragon', 'Ice', 700],
#  ['Water', 'Fighting', 580],
#  ['Water', 'Fighting', 580],
#  ['Normal', 'Psychic', 600],
#  ['Normal', 'Fighting', 600],
#  ['Bug', 'Steel', 600],
#  ['Grass', nan, 313],
#  ['Grass', nan, 405],
#  ['Grass', 'Fighting', 530],
#  ['Fire', nan, 307],
#  ['Fire', nan, 409],
#  ['Fire', 'Psychic', 534],
#  ['Water', nan, 314],
#  ['Water', nan, 405],
#  ['Water', 'Dark', 530],
#  ['Normal', nan, 237],
#  ['Normal', 'Ground', 423],
#  ['Normal', 'Flying', 278],
#  ['Fire', 'Flying', 382],
#  ['Fire', 'Flying', 499],
#  ['Bug', nan, 200],
#  ['Bug', nan, 213],
#  ['Bug', 'Flying', 411],
#  ['Fire', 'Normal', 369],
#  ['Fire', 'Normal', 507],
#  ['Fairy', nan, 303],
#  ['Fairy', nan, 371],
#  ['Fairy', nan, 552],
#  ['Grass', nan, 350],
#  ['Grass', nan, 531],
#  ['Fighting', nan, 348],
#  ['Fighting', 'Dark', 495],
#  ['Normal', nan, 472],
#  ['Psychic', nan, 355],
#  ['Psychic', nan, 466],
#  ['Psychic', nan, 466],
#  ['Steel', 'Ghost', 325],
#  ['Steel', 'Ghost', 448],
#  ['Steel', 'Ghost', 520],
#  ['Steel', 'Ghost', 520],
#  ['Fairy', nan, 341],
#  ['Fairy', nan, 462],
#  ['Fairy', nan, 341],
#  ['Fairy', nan, 480],
#  ['Dark', 'Psychic', 288],
#  ['Dark', 'Psychic', 482],
#  ['Rock', 'Water', 306],
#  ['Rock', 'Water', 500],
#  ['Poison', 'Water', 320],
#  ['Poison', 'Dragon', 494],
#  ['Water', nan, 330],
#  ['Water', nan, 500],
#  ['Electric', 'Normal', 289],
#  ['Electric', 'Normal', 481],
#  ['Rock', 'Dragon', 362],
#  ['Rock', 'Dragon', 521],
#  ['Rock', 'Ice', 362],
#  ['Rock', 'Ice', 521],
#  ['Fairy', nan, 525],
#  ['Fighting', 'Flying', 500],
#  ['Electric', 'Fairy', 431],
#  ['Rock', 'Fairy', 500],
#  ['Dragon', nan, 300],
#  ['Dragon', nan, 452],
#  ['Dragon', nan, 600],
#  ['Steel', 'Fairy', 470],
#  ['Ghost', 'Grass', 309],
#  ['Ghost', 'Grass', 474],
#  ['Ghost', 'Grass', 335],
#  ['Ghost', 'Grass', 335],
#  ['Ghost', 'Grass', 335],
#  ['Ghost', 'Grass', 335],
#  ['Ghost', 'Grass', 494],
#  ['Ghost', 'Grass', 494],
#  ['Ghost', 'Grass', 494],
#  ['Ghost', 'Grass', 494],
#  ['Ice', nan, 304],
#  ['Ice', nan, 514],
#  ['Flying', 'Dragon', 245],
#  ['Flying', 'Dragon', 535],
#  ['Fairy', nan, 680],
#  ['Dark', 'Flying', 680],
#  ['Dragon', 'Ground', 600],
#  ['Rock', 'Fairy', 600],
#  ['Rock', 'Fairy', 700],
#  ['Psychic', 'Ghost', 600],
#  ['Psychic', 'Dark', 680],
#  ['Fire', 'Water', 600]]

# %% [markdown]
# #### Now we run ANOVA test on `pokemon_totals`.
#
# *Hints:*
#
# * To conduct ANOVA, you can use `scipy.stats.f_oneway()`. Here's the [reference](http://b.link/scipy44).
#
# * What if `f_oneway` throws an error because it does not accept `pokemon_totals` as a list? The trick is to add a `*` in front of `pokemon_totals`, e.g. `stats.f_oneway(*pokemon_groups)`. This trick breaks the list and supplies each list item as a parameter for `f_oneway`.

# %%
from scipy.stats import f_oneway

# Extract the 'Total' column from the pokemon_groups dataframe
pokemon_totals = [group[2] for group in pokemon_groups]

# Conduct the ANOVA test
f_stat, p_value = f_oneway(*pokemon_totals)

# Print the results
print("F-statistic: ", f_stat)
print("P-value: ", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\1193534576.py in <module>
#       5
#       6 # Conduct the ANOVA test
# ----> 7 f_stat, p_value = f_oneway(*pokemon_totals)
#       8
#       9 # Print the results
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_py.py in f_oneway(axis, *samples)
#    3861     # if the dimensions of all the arrays, except the axis dimension, are not
#    3862     # the same.
# -> 3863     alldata = np.concatenate(samples, axis=axis)
#    3864     bign = alldata.shape[axis]
#    3865
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
# This code first extracts the 'Total' column from the pokemon_groups dataframe and assigns it to the variable pokemon_totals, then it uses the f_oneway() function to conduct the ANOVA test on the pokemon_totals data.

# The f_oneway() function returns two values: the F-statistic and the p-value. The F-statistic is a measure of how much variation there is between the means of the groups, and the p-value is the probability that the null hypothesis (that the means of the groups are equal) is true.

# The results of the ANOVA test can be interpreted as follows:

# If the p-value is less than the significance level (usually 0.05), then we reject the null hypothesis and conclude that there is a significant difference in the means of the groups.
# If the p-value is greater than the significance level, then we fail to reject the null hypothesis and conclude that there is not a significant difference in the means of the groups

# %%
# As a side note, you should make sure that the assumptions of ANOVA are met before conducting the test, such as normality and equal variances among groups. Also it's important to note that you should check the type of your Type1 and Type2 columns, if they are not categorical, you should convert them to categorical before running ANOVA.

# %%
# Your code here

# %%
# The error message you're seeing is indicating that the np.concatenate() function is trying to concatenate zero-dimensional arrays, which is not allowed. This is likely happening because the pokemon_totals variable is a list of lists containing empty lists, and the f_oneway() function is trying to concatenate them together, resulting in the error.

# To fix this, you need to make sure that the pokemon_totals variable contains only non-empty lists. You can do this by checking for empty lists before passing them to the f_oneway() function:

# %%
pokemon_totals = [group[2] for group in pokemon_groups if group[2]]

# %%
# nother thing is that, you should make sure that the input passed to the f_oneway function is a list of lists, each containing the data for one group, so the f_oneway function knows which data belongs to which group.

# %%
pokemon_totals = [[group[2] for group in pokemon_groups if group[0]=='Type1'], [group[2] for group in pokemon_groups if group[0]=='Type2'], ...]

# %%
# This way you can pass the list of lists to the f_oneway function.

# Also, it's important to check the type of your Type1 and Type2 columns, if they are not categorical, you should convert them to categorical before running ANOVA.

# Finally, make sure that the input passed to the f_oneway function is a list of lists, each containing the data for one group, so the f_oneway function knows which data belongs to which group.

# %%
from scipy.stats import f_oneway

# Extract the 'Total' column from the pokemon_groups dataframe
pokemon_totals = [group[2] for group in pokemon_groups]

# Conduct the ANOVA test
f_stat, p_value = f_oneway(*pokemon_totals)

# Print the results
print("F-statistic: ", f_stat)
print("P-value: ", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11400\1793725556.py in <module>
#       5
#       6 # Conduct the ANOVA test
# ----> 7 f_stat, p_value = f_oneway(*pokemon_totals)
#       8
#       9 # Print the results
#
# ~\anaconda3\lib\site-packages\scipy\stats\_stats_py.py in f_oneway(axis, *samples)
#    3861     # if the dimensions of all the arrays, except the axis dimension, are not
#    3862     # the same.
# -> 3863     alldata = np.concatenate(samples, axis=axis)
#    3864     bign = alldata.shape[axis]
#    3865
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
# interest_r = pd.read_csv('rate_by_city.csv')
# interest_r.head(60)
# interest_r.to_excel('rate_by_city.xlsx', index=False)

# %%
# interest_r[interest_r.City==1].Rate

# %%
# interest_r['city_count'] = interest_r.groupby('City').cumcount() ##is the new index 

# interest_r_pivot = interest_r.pivot(index='city_count', columns='City', values='Rate')
# interest_r_pivot.columns = ['City_'+str(x) for x in interest_r_pivot.columns.values]
# interest_r_pivot.head(30)

# %%
# interest_r['city_count'] = interest_r.groupby('City').cumcount() ##is the new index

# %% [markdown]
# #### Interpret the ANOVA test result. Is the difference significant?

# %%
# Your comment here
